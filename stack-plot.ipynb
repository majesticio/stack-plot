# %% [markdown]
# # Stack Plot Example Using Random Numbers

# %%
# import packages
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Create some random data to plot

# %%
x = range(1,21)
y1 = np.random.rand(20)
y2 = np.random.rand(20)

#print values to see what we have
print(x)
print(y1)
print(y2)
# Out:
# range(1, 21)
# [0.7024797  0.44607438 0.42160843 0.13859388 0.62020614 0.22502087
#  0.18678388 0.37261898 0.3699413  0.79247326 0.56580083 0.88520897
#  0.1138903  0.33590627 0.16156007 0.33676604 0.36854053 0.84391867
#  0.67183126 0.53260274]
# [0.14760302 0.50931787 0.74789212 0.98149359 0.66139449 0.61596274
#  0.07653403 0.1108117  0.01319552 0.58231146 0.48563986 0.5738657
#  0.81040795 0.75030382 0.20089371 0.73359499 0.25512936 0.22972618
#  0.06078299 0.46406059]

# %%
# setup legend for plot
plt.plot([], [], color='r', label = 'y1')
plt.plot([], [], color='b', label = 'y2')

#setup the plot 
plt.stackplot(x, y1, y2, colors= ['r', 'b'])
plt.title('Stack Plot Random Numbers')
plt.legend()
plt.show()
